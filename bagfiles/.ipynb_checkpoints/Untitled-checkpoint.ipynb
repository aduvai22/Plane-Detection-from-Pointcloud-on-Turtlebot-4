# %%
import rosbag
# from bagpy import bagreader

# b = bagreader('./rosbag2_2023_03_29-18_00_58/rosbag2_2023_03_29-18_00_58_0.db3')

# get the list of topics
# print(b.topic_table)

# # get all the messages of type velocity
# velmsgs   = b.vel_data()
# veldf = pd.read_csv(velmsgs[0])
# plt.plot(veldf['Time'], veldf['linear.x'])

# # quickly plot velocities
# b.plot_vel(save_fig=True)

# # you can animate a timeseries data
# bagpy.animate_timeseries(veldf['Time'], veldf['linear.x'], title='Velocity Timeseries Plot')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipykernel_78820/214534158.py in <module>
# ----> 1 import rosbag
#       2 # from bagpy import bagreader
#       3
#       4 # b = bagreader('./rosbag2_2023_03_29-18_00_58/rosbag2_2023_03_29-18_00_58_0.db3')
#       5
#
# ~/anaconda3/lib/python3.9/site-packages/rosbag/__init__.py in <module>
#      31 # POSSIBILITY OF SUCH DAMAGE.
#      32
# ---> 33 from .bag import Bag, Compression, ROSBagException, ROSBagFormatException, ROSBagUnindexedException
#      34
#      35 # Import rosbag main to be used by the rosbag executable
#
# ~/anaconda3/lib/python3.9/site-packages/rosbag/bag.py in <module>
#      67
#      68 import roslib.names # still needed for roslib.names.canonicalize_name()
# ---> 69 import rospy
#      70 try:
#      71     import roslz4
#
# ~/anaconda3/lib/python3.9/site-packages/rospy/__init__.py in <module>
#      47 from std_msgs.msg import Header
#      48
# ---> 49 from .client import spin, myargv, init_node, \
#      50     get_published_topics, \
#      51     wait_for_message, \
#
# ~/anaconda3/lib/python3.9/site-packages/rospy/client.py in <module>
#      52 import roslib
#      53
# ---> 54 import rospy.core
#      55 from rospy.core import logwarn, loginfo, logerr, logdebug
#      56 import rospy.exceptions
#
# ~/anaconda3/lib/python3.9/site-packages/rospy/core.py in <module>
#      73 from rospy.impl.validators import ParameterInvalid
#      74
# ---> 75 from rosgraph_msgs.msg import Log
#      76 from functools import partial
#      77
#
# ImportError: cannot import name 'Log' from 'rosgraph_msgs.msg' (/opt/ros/galactic/lib/python3.8/site-packages/rosgraph_msgs/msg/__init__.py)

# %%
import pandas as pd

df = pd.read_csv('./result/messages.csv')

# %%
df
# Out:
#       id  topic_id   timestamp                                  data
# 0      1         1   744439530  unknown_value_please_contact_support
# 1      2         1   890144292  unknown_value_please_contact_support
# 2      3         1  1039121492  unknown_value_please_contact_support
# 3      4         1  1186429374  unknown_value_please_contact_support
# 4      5         1  1333869497  unknown_value_please_contact_support
# ..   ...       ...         ...                                   ...
# 127  128         1 -1989463360  unknown_value_please_contact_support
# 128  129         1 -1839825067  unknown_value_please_contact_support
# 129  130         1 -1694554410  unknown_value_please_contact_support
# 130  131         1 -1546597464  unknown_value_please_contact_support
# 131  132         1 -1400357664  unknown_value_please_contact_support
#
# [132 rows x 4 columns]

# %%
import pandas as pd

df = pd.read_csv('./result/messages.columns')

# %%
df
# Out:
#         name     type  length  leftDigits  rightDigits
# 0         id  INTEGER       3           3            0
# 1   topic_id  INTEGER       1           1            0
# 2  timestamp  INTEGER      11          10            0
# 3       data   STRING      36           0            0

# %%
from rosbags.rosbag2 import Reader
from rosbags.serde import deserialize_cdr

# %%
# create reader instance and open for reading
with Reader('/home/adnana/rosbag2_2023_04_05-17_19_07') as reader:
    # topic and msgtype information is available on .connections list
    for connection in reader.connections:
        print(connection.topic, connection.msgtype)

    # iterate over messages
    for connection, timestamp, rawdata in reader.messages():
        if connection.topic == '/scan':
            msg = deserialize_cdr(rawdata, connection.msgtype)
            print(msg.header.frame_id)
# Out:
# /scan sensor_msgs/msg/LaserScan
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link
# rplidar_link

# %%
msg.ranges
# Out:
# sensor_msgs__msg__LaserScan(header=std_msgs__msg__Header(stamp=builtin_interfaces__msg__Time(sec=1680729565, nanosec=457680110, __msgtype__='builtin_interfaces/msg/Time'), frame_id='rplidar_link', __msgtype__='std_msgs/msg/Header'), angle_min=-3.1241393089294434, angle_max=3.1415927410125732, angle_increment=0.008714509196579456, time_increment=0.00020395781029947102, scan_time=0.1466456651687622, range_min=0.15000000596046448, range_max=12.0, ranges=array([2.056, 2.056, 2.064, 2.076, 2.072, 2.08 , 2.084, 2.084, 0.798,
#        0.798, 0.786, 0.786, 0.766, 0.732, 0.732, 0.724, 0.724, 0.704,
#        0.686, 0.678, 0.66 , 0.648, 0.638, 0.626, 0.612, 0.606, 0.594,
#        0.582, 0.57 , 0.564, 0.554, 0.544, 0.538, 0.528, 0.518, 0.515,
#        0.507, 0.498, 0.491, 0.486, 0.479, 0.472, 0.468, 0.462, 0.455,
#        0.449, 0.446, 0.439, 0.434, 0.431, 0.426, 0.424, 0.417, 0.413,
#        0.408, 0.405, 0.401, 0.396, 0.394, 0.39 , 0.386, 0.384, 0.38 ,
#        0.376, 0.374, 0.37 , 0.367, 0.365, 0.361, 0.358, 0.356, 0.354,
#        0.35 , 0.348, 0.346, 0.343, 0.342, 0.339, 0.336, 0.335, 0.332,
#        0.33 , 0.329, 0.326, 0.324, 0.323, 0.321, 0.32 , 0.317, 0.316,
#        0.313, 0.313, 0.311, 0.31 , 0.308, 0.306, 0.305, 0.304, 0.302,
#        0.301, 0.299, 0.298, 0.297, 0.296, 0.295, 0.294, 0.292, 0.292,
#        0.291, 0.289, 0.289, 0.288, 0.287, 0.286, 0.285, 0.285, 0.284,
#        0.283, 0.282, 0.281, 0.281, 0.28 , 0.279, 0.279, 0.278, 0.277,
#        0.277, 0.276, 0.276, 0.275, 0.275, 0.275, 0.274, 0.274, 0.273,
#        0.273, 0.273, 0.272, 0.272, 0.271, 0.271, 0.271, 0.271, 0.271,
#        0.27 , 0.27 , 0.27 , 0.27 , 0.27 , 0.27 , 0.27 , 0.27 , 0.27 ,
#        0.27 , 0.27 , 0.27 , 0.27 , 0.27 , 0.27 , 0.27 , 0.27 , 0.271,
